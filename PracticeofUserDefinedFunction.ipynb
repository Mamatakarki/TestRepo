# %% [markdown]
# # You're given a dataset of student grades and need to determine the grade distribution
#
# # Question:Write a python function grade distribution (grades) that takes a list of integers representing student grade(0-100). use a loop to count the number of grades in each grade category:
#
# # 'A' (90-100), 'B'(80-89), 'C'(70-79), 'D'(60-69), and 'F'(below 60)
#
# # use if elif -else statement within the loop to categorize the grades. return a dictionery with the counts of each grade category.

# %%
grade = float(input("Enter the student grade"))
total =0
for i in range(total+1):
    if 90<=grade<=100:
        print("A grade")
    elif 80<=grade<=89:
        print("B grade")
    elif 70<=grade<=79:
        print("C grade")
    elif 60<=grade<=69:
        print("D grade")
    elif grade<=60:
        print("F grade")
    else:
        print("fail")
# Out:
# Enter the student grade 67
# D grade

# %%
def grade_distribution(grades):
    grades
    for grade in grades:
        if 90<=grade<=100:
            print(" You have 'A' grade")
        elif 80<=grade<=89:
            print("You have 'B' grade")
        elif 70<=grade<=79:
            print("You have 'C' grade")
        elif 60<=grade<=69:
            print("You have 'D' grade")
        elif grade<=60:
            print("You have 'F' grade")
        
    return

# %%
#grades = [98,78,92,88,72,40,50,65]
grade_distribution(grades)
# Out:
#  You have 'A' grade
# You have 'C' grade
#  You have 'A' grade
# You have 'B' grade
# You have 'C' grade
# You have 'F' grade
# You have 'F' grade
# You have 'D' grade

# %% [markdown]
# # Even or Odd Checker
#
# # Create a function check_even_odd(num) that checks whether a number is even or odd.

# %%
def my_func():
    number = int(input("Enter a number:"))
    for i in range(1, number + 1):
        if i%2 == 0:
            print(f"{i} is even number")
        else:
            print(f"{i} is odd number")
    return

# %%
 my_func()
# Out:
# Enter a number: 9
# 1 is odd number
# 2 is even number
# 3 is odd number
# 4 is even number
# 5 is odd number
# 6 is even number
# 7 is odd number
# 8 is even number
# 9 is odd number

# %%
def my_func():
    number = int(input("Enter a number: "))
    for i in range(1, number + 1):
        if i % 2 == 0:
            print(f"{i} is even")
        else:
            print(f"{i} is odd")

# Call the function
my_func()
# Out:
# Enter a number:  9
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd

# %%
def is_even(num):
    if num % 2 == 0:
        return True
    else:
        return False

print(is_even(4))  # Output: True
print(is_even(7))  # Output: False
# Out:
# True
# False

# %%
def add(a,b):
    return a+b

result = add(3,5)
print(result)
# Out:
# 8

# %%
def square(n):
    return n*n
print(square(6))
# Out:
# 36

# %% [markdown]
# # Check Armstrong Number
#
# # Write a function is_armstrong(n) that checks if a number is an Armstrong numbe

# %%
##def arm_strong():
num = int(input("Enter a number"))
sum=0
temp=num

while temp>0:
    digit = temp%10
    cube = digit**3
    sum = sum+cube
    temp//=10
if sum==num:
     print("It is armstrong")
else:
    print("It is not armstrong")
# Out:
# Enter a number 153
# It is armstrong

# %%
##arm_strong()
# Out:
# Enter a number 88
# It is not armstrong
# It is not armstrong

# %%
def is_armstrong(n):
    sum = 0
    temp = n

    while temp > 0:
        digit = temp % 10
        sum += digit ** 3
        temp //= 10

    if sum == n:
        return True
    else:
        return False

# Example usage:
num = int(input("Enter a number: "))
if is_armstrong(num):
    print("It is an Armstrong number.")
else:
    print("It is not an Armstrong number.")
# Out:
# Enter a number:  370
# It is an Armstrong number.

# %%
import random
def number_guessing_game():
    secret_number = random.randint(1, 100)
    print(secret_number)

# %%
number_guessing_game()
# Out:
# 22

# %% [markdown]
# # You are creating a number guessing game where the computer generate a random number between 1 to 100 and the playerhas to guess it. write a python code to generate a random number between 1 to 100 use control flow statement and loops to allow the player to guess the number and provide feedback(too high, too low, correct) define a user defined function to encapsulate the game logic and call this function to play the game.

# %%
import random

def number_guessing_game():
    
    secret_number = random.randint(1, 100)
    print(secret_number)
    print("Welcome to the number gueesing game")
    print("I have choosen the number between 1 to 100. can you guess it?")
    attempts = 0
    guess = None
    while guess!= secret_number:
        guess = int(input("Enter you guess number"))
        attempts = attempts+1
        if guess>secret_number:
            print("Too high, Try again")
        elif guess<secret_number:
            print("Too low, Try again")
        else:
            print(f"🎯 Congratulations! You guessed the number in {attempts} attempts.")

# %%
number_guessing_game()
# Out:
# 12
# Welcome to the number gueesing game
# I have choosen the number between 1 to 100. can you guess it?
# Enter you guess number 49
# Too high, Try again
# Enter you guess number 11
# Too low, Try again
# Enter you guess number 12
# 🎯 Congratulations! You guessed the number in 3 attempts.

# %%
for i in range(3):
    
    print(i)
# Out:
# 0
# 1
# 2

# %%
count = 0
while count<5:
    print("Helloe")
    count += 1
# Out:
# Helloe
# Helloe
# Helloe
# Helloe
# Helloe
